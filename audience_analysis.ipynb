# %% [markdown]
# 90 Days - (1 MAR 2023 - 1 JUN 2023)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# Individual Level

# %%
session_data = pd.read_excel('session_data.xlsx')
session_data
# Out:
#           Client Id  Sessions  Avg. Session Duration  Bounce Rate  Revenue  \
# 0      1.107936e+09       146             865.767123     0.184932      0.0
# 1      3.533322e+08        97            1791.484536     0.164948      0.0
# 2      1.856038e+09        87             692.620690     0.356322      0.0
# 3      1.705517e+09        73             993.260274     0.150685      0.0
# 4      1.275477e+09        62             103.516129     0.564516      0.0
# ...             ...       ...                    ...          ...      ...
# 12312  9.981598e+08         1               0.000000     1.000000      0.0
# 12313  9.984486e+08         1               0.000000     1.000000      0.0
# 12314  9.990409e+08         1               0.000000     1.000000      0.0
# 12315  9.996209e+08         1              38.000000     0.000000      0.0
# 12316  9.998109e+08         1               0.000000     1.000000      0.0
#
#        Transactions  Goal Conversion Rate
# ...

# %%
print('Mean Bounce Rate was ', np.mean(session_data['Bounce Rate']))
print('Mean Avg. Session Duration was ', np.mean(session_data['Avg. Session Duration']))
print('Max Avg. Session Duration was ', np.max(session_data['Avg. Session Duration']))
print('Min Avg. Session Duration was ', np.min(session_data['Avg. Session Duration']))
print('Mean Revenue was ', np.mean(session_data['Revenue']))
print('Max Revenue was ', np.max(session_data['Revenue']))
print('Min Revenue was ', np.min(session_data['Revenue']))
print('Max Transcations was ', np.max(session_data['Transactions']))
print('Mean Transcations was ', np.mean(session_data['Transactions']))
print('Mean Goal Conversion Rate was ', np.mean(session_data['Goal Conversion Rate']))
print('Max Goal Conversion Rate was ', np.max(session_data['Goal Conversion Rate']))
print('Mean Sessions was ', np.mean(session_data['Sessions']))
print('Max Sessions was ', np.max(session_data['Sessions']))
# Out:
# Mean Bounce Rate was  0.6957786938184064
# Mean Avg. Session Duration was  70.49931483433454
# Max Avg. Session Duration was  5233.0
# Min Avg. Session Duration was  0.0
# Mean Revenue was  5.639626318259317
# Max Revenue was  3504.0
# Min Revenue was  0.0
# Max Transcations was  4
# Mean Transcations was  0.0180238694487294
# Mean Goal Conversion Rate was  0.0
# Max Goal Conversion Rate was  0
# Mean Sessions was  1.4263213444832346
# Max Sessions was  146

# %%
import matplotlib.pyplot as plt
plt.plot(session_data['Sessions'], session_data['Avg. Session Duration'], marker='o', linestyle='-', color='b')
plt.xlabel('Sessions')
plt.ylabel('Avg. Session Duration')
plt.title('Line Plot')
plt.show()

# %%
len(session_data[session_data['Avg. Session Duration'] < 10]), len(session_data)
# Out:
# (8449, 12317)

# %% [markdown]
# Majority of the people who spend large amount of time have less sessions. Looks like they know what they want and website helps them find it.

# %%
import matplotlib.pyplot as plt
plt.plot(session_data['Revenue'], session_data['Avg. Session Duration'], marker='o', linestyle=None, color='g')
plt.xlabel('Revenue')
plt.ylabel('Avg. Session Duration')
plt.title('Line Plot')
plt.show()

# %%
bins = [0, 0.2, 0.4, 0.6, 0.8, 1]
print(pd.cut(session_data['Bounce Rate'], bins).value_counts())
# Out:
# (0.8, 1.0]    8042
# (0.4, 0.6]     580
# (0.6, 0.8]     253
# (0.2, 0.4]     174
# (0.0, 0.2]      38
# Name: Bounce Rate, dtype: int64

# %%
bins = [0, 1000, 2000, 3000, 4000, 5000]
print(pd.cut(session_data['Revenue'], bins).value_counts())
# Out:
# (0, 1000]       176
# (1000, 2000]      6
# (2000, 3000]      1
# (3000, 4000]      1
# (4000, 5000]      0
# Name: Revenue, dtype: int64

# %% [markdown]
# Age Level

# %%
age_data = pd.read_excel('age_data.xlsx')
age_data
# Out:
#      Age  Users  New Users  Sessions  Bounce Rate  Pages / Session  \
# 0  25-34    709        684      1127     0.600710         2.700976
# 1  35-44    545        530       832     0.585337         2.639423
# 2  18-24    482        463       919     0.524483         4.266594
# 3  45-54    312        303       518     0.590734         5.092664
# 4  55-64    203        198       280     0.614286         2.432143
# 5    65+     97         95       164     0.689024         1.847561
# 6    NaN   2348       2273      3840     0.582552         3.328906
#
#    Avg. Session Duration  Transactions   Revenue  Ecommerce Conversion Rate
# 0             129.024845            12   3458.89                   0.010648
# 1             124.429087             5   2018.30                   0.006010
# 2             267.420022            10   3108.64                   0.010881
# 3             278.758687             5   3656.00                   0.009653
# ...

# %%
age_data.dtypes
# Out:
# Age                           object
# Users                          int64
# New Users                      int64
# Sessions                       int64
# Bounce Rate                  float64
# Pages / Session              float64
# Avg. Session Duration        float64
# Transactions                   int64
# Revenue                      float64
# Ecommerce Conversion Rate    float64
# dtype: object

# %%
age_data['Age'] = age_data['Age'].astype(str)

# %%
sorted_indices = sorted(range(len(age_data['Age'])), key=lambda k: age_data['Age'][k])
x_sorted = [age_data['Age'] [i] for i in sorted_indices]
y_sorted = [age_data['Users'][i] for i in sorted_indices]
plt.bar(x_sorted, y_sorted)
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.title('Count of Values in Each Range')
plt.savefig('Plots/1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sorted_indices = sorted(range(len(age_data['Age'])), key=lambda k: age_data['Age'][k])
x_sorted = [age_data['Age'] [i] for i in sorted_indices]
y_sorted = [age_data['Revenue'][i] for i in sorted_indices]
plt.bar(x_sorted, y_sorted)
plt.xlabel('Age Range')
plt.ylabel('Revenue')
plt.title('Revenue of Values in Each Range')
plt.savefig('Plots/2.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# The age group 45-54 with less users gives out more revenue. More targeting is needed for other groups because it has a good size and can yield more than what they are giving out right now.

# %%
sorted_indices = sorted(range(len(age_data['Age'])), key=lambda k: age_data['Age'][k])
x_sorted = [age_data['Age'] [i] for i in sorted_indices]
y_sorted = [age_data['Avg. Session Duration'][i] for i in sorted_indices]
plt.bar(x_sorted, y_sorted)
plt.xlabel('Age Range')
plt.ylabel('Avg. Session Duration')
plt.title('Avg. Session Duration of Values in Each Range')
plt.savefig('Plots/3.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Funny stuff, 18-24 age group spends so much time on the pages but buys nothing. Gotta motivate them! They have a good enough size.

# %%
sorted_indices = sorted(range(len(age_data['Age'])), key=lambda k: age_data['Age'][k])
x_sorted = [age_data['Age'] [i] for i in sorted_indices]
y_sorted = [age_data['Pages / Session'][i] for i in sorted_indices]
plt.bar(x_sorted, y_sorted)
plt.xlabel('Age Range')
plt.ylabel('Pages / Session')
plt.title('Pages / Session of Values in Each Range')
plt.savefig('Plots/4.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sorted_indices = sorted(range(len(age_data['Age'])), key=lambda k: age_data['Age'][k])
x_sorted = [age_data['Age'] [i] for i in sorted_indices]
y_sorted = [age_data['Ecommerce Conversion Rate'][i] for i in sorted_indices]
plt.bar(x_sorted, y_sorted)
plt.xlabel('Age Range')
plt.ylabel('Ecommerce Conversion Rate')
plt.title('Ecommerce Conversion Rate of Values in Each Range')
plt.savefig('Plots/5.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Gender Level

# %%
gender_data = pd.read_excel('gender_data.xlsx')
gender_data
# Out:
#    Gender  Users  New Users  Sessions  Bounce Rate  Pages / Session  \
# 0    male   1407       1377      2148     0.623836         2.399907
# 1  female   1152       1121      2016     0.556052         4.137897
# 2     NaN   2559       2498      4164     0.591018         3.241354
#
#    Avg. Session Duration  Transactions   Revenue  Ecommerce Conversion Rate
# 0             120.095438            20   8242.25                   0.009311
# 1             230.742560            23   7584.27                   0.011409
# 2             173.665226            43  15826.52                   0.010327

# %%
gender_data.dtypes
# Out:
# Gender                        object
# Users                          int64
# New Users                      int64
# Sessions                       int64
# Bounce Rate                  float64
# Pages / Session              float64
# Avg. Session Duration        float64
# Transactions                   int64
# Revenue                      float64
# Ecommerce Conversion Rate    float64
# dtype: object

# %%
gender_data['Gender'] = gender_data['Gender'].astype(str)
plt.bar(gender_data['Gender'], gender_data['Users'])
plt.xlabel('Gender Range')
plt.ylabel('Users')
plt.title('Users vs Gender')
plt.savefig('Plots/6.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.bar(gender_data['Gender'], gender_data['Revenue'])
plt.xlabel('Gender Range')
plt.ylabel('Revenue')
plt.title('Revenue vs Gender')
plt.savefig('Plots/7.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.bar(gender_data['Gender'], gender_data['Sessions'])
plt.xlabel('Gender Range')
plt.ylabel('Sessions')
plt.title('Sessions vs Gender')
plt.savefig('Plots/8.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.bar(gender_data['Gender'], gender_data['Pages / Session'])
plt.xlabel('Gender Range')
plt.ylabel('Pages / Session')
plt.title('Pages / Session vs Gender')
plt.savefig('Plots/9.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.bar(gender_data['Gender'], gender_data['Avg. Session Duration'])
plt.xlabel('Gender Range')
plt.ylabel('Avg. Session Duration')
plt.title('Avg. Session Duration vs Gender')
plt.savefig('Plots/10.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.bar(gender_data['Gender'], gender_data['Transactions'])
plt.xlabel('Gender Range')
plt.ylabel('Transactions')
plt.title('Transactions vs Gender')
plt.savefig('Plots/111.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Country Level

# %%
country_data = pd.read_excel('country_data.xlsx')
country_data
# Out:
#                Country  Users  New Users  Sessions  Bounce Rate  \
# 0        United States  11311      11248     16093     0.671534
# 1       United Kingdom    246        241       352     0.451705
# 2               Canada    198        197       261     0.513410
# 3            (not set)     88         88        88     1.000000
# 4                India     81         75       118     0.483051
# 5          South Korea     35         35        43     0.604651
# 6              Nigeria     31         31        39     0.487179
# 7              Germany     29         29        51     0.588235
# 8                Italy     28         25        66     0.257576
# 9            Australia     21         21        33     0.515152
# 10           Indonesia     19         18        19     0.473684
# 11              Sweden     19         18        20     0.700000
# 12             Ireland     16         16        16     1.000000
# 13            Pakistan     16         14        41     0.682927
# ...

# %%
country_data.dtypes
# Out:
# Country                       object
# Users                          int64
# New Users                      int64
# Sessions                       int64
# Bounce Rate                  float64
# Pages / Session              float64
# Avg. Session Duration        float64
# Transactions                   int64
# Revenue                      float64
# Ecommerce Conversion Rate    float64
# dtype: object

# %%
country_data['Country'] = country_data['Country'].astype(str)
sorted_data = sorted(zip(country_data['Avg. Session Duration'], country_data['Country']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:10]
y_new = sorted_y[:10]
plt.bar(x_new, y_new)
plt.xlabel('Country Range')
plt.ylabel('Avg. Session Duration')
plt.xticks(rotation = 90)
plt.title('Avg. Session Duration vs Country')
plt.savefig('Plots/12.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sorted_data = sorted(zip(country_data['Users'], country_data['Country']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:10]
y_new = sorted_y[:10]
plt.bar(x_new, y_new)
plt.xlabel('Country Range')
plt.ylabel('Users')
plt.xticks(rotation = 90)
plt.title('Users vs Country')
plt.savefig('Plots/13.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sorted_data = sorted(zip(country_data['New Users'], country_data['Country']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:10]
y_new = sorted_y[:10]
plt.bar(x_new, y_new)
plt.xlabel('Country Range')
plt.ylabel('New Users')
plt.xticks(rotation = 90)
plt.title('New Users vs Country')
plt.savefig('Plots/14.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sorted_data = sorted(zip(country_data['Revenue'], country_data['Country']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:10]
y_new = sorted_y[:10]
plt.bar(x_new, y_new)
plt.xlabel('Country Range')
plt.ylabel('Revenue')
plt.xticks(rotation = 90)
plt.title('Revenue vs Country')
plt.savefig('Plots/15.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sorted_data = sorted(zip(country_data['Pages / Session'], country_data['Country']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:10]
y_new = sorted_y[:10]
plt.bar(x_new, y_new)
plt.xlabel('Country Range')
plt.ylabel('Pages / Session')
plt.xticks(rotation = 90)
plt.title('Pages / Session vs Country')
plt.savefig('Plots/16.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# State Level

# %%
state_data = pd.read_excel('us_state_data.xlsx')
state_data
# Out:
#                   Region  Users  New Users  Sessions  Bounce Rate  \
# 0               Virginia   1448       1405      1549     0.893480
# 1             California   1278       1230      1723     0.634939
# 2                  Texas    846        807      1179     0.642070
# 3               New York    744        695      1538     0.506502
# 4                Florida    535        496       696     0.652299
# 5             Washington    467        432       666     0.635135
# 6                Georgia    430        382       534     0.700375
# 7               Illinois    409        372       527     0.675522
# 8               Colorado    395        358       592     0.645270
# 9         North Carolina    384        343       465     0.761290
# 10                  Ohio    334        299       419     0.642005
# 11              Michigan    331        300       386     0.681347
# 12          Pennsylvania    330        307       389     0.691517
# ...

# %%
state_data['Region'] = state_data['Region'].astype(str)
sorted_data = sorted(zip(state_data['Pages / Session'], state_data['Region']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:30]
y_new = sorted_y[:30]
plt.bar(x_new, y_new)
plt.xlabel('Region Range')
plt.ylabel('Pages / Session')
plt.xticks(rotation = 90)
plt.title('Pages / Session vs Region')
plt.savefig('Plots/17.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
state_data['Region'] = state_data['Region'].astype(str)
sorted_data = sorted(zip(state_data['Revenue'], state_data['Region']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:30]
y_new = sorted_y[:30]
plt.bar(x_new, y_new)
plt.xlabel('Region Range')
plt.ylabel('Revenue')
plt.xticks(rotation = 90)
plt.title('Revenue vs Region')
plt.savefig('Plots/18.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
state_data['Region'] = state_data['Region'].astype(str)
sorted_data = sorted(zip(state_data['Users'], state_data['Region']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:30]
y_new = sorted_y[:30]
plt.bar(x_new, y_new)
plt.xlabel('Region Range')
plt.ylabel('Users')
plt.xticks(rotation = 90)
plt.title('Users vs Region')
plt.savefig('Plots/19.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
state_data['Region'] = state_data['Region'].astype(str)
sorted_data = sorted(zip(state_data['New Users'], state_data['Region']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:30]
y_new = sorted_y[:30]
plt.bar(x_new, y_new)
plt.xlabel('Region Range')
plt.ylabel('New Users')
plt.xticks(rotation = 90)
plt.title('New Users vs Region')
plt.savefig('Plots/20.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
state_data['Region'] = state_data['Region'].astype(str)
sorted_data = sorted(zip(state_data['Avg. Session Duration'], state_data['Region']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:30]
y_new = sorted_y[:30]
plt.bar(x_new, y_new)
plt.xlabel('Region Range')
plt.ylabel('Avg. Session Duration')
plt.xticks(rotation = 90)
plt.title('Avg. Session Duration vs Region')
plt.savefig('Plots/21.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
state_data['Region'] = state_data['Region'].astype(str)
sorted_data = sorted(zip(state_data['Bounce Rate'], state_data['Region']), reverse=True)
sorted_y, sorted_x = zip(*sorted_data)
x_new = sorted_x[:30]
y_new = sorted_y[:30]
plt.bar(x_new, y_new)
plt.xlabel('Region Range')
plt.ylabel('Bounce Rate')
plt.xticks(rotation = 90)
plt.title('Bounce Rate vs Region')
plt.savefig('Plots/22.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# User Behaviour

# %%
user_behaviour = pd.read_excel('user_behaviour.xlsx')
user_behaviour
# Out:
#            User Type  Users  New Users  Sessions  Bounce Rate  \
# 0        New Visitor  12262      12251     12236     0.679797
# 1  Returning Visitor   2133          0      5332     0.608027
# 2                NaN  14395      12251     17568     0.658015
#
#    Pages / Session  Avg. Session Duration  Transactions       Revenue  \
# 0         2.114743              80.543723            80  21302.170000
# 1         3.492686             220.793323           142  48161.107362
# 2         2.532958             123.110371           222  69463.277362
#
#    Ecommerce Conversion Rate
# 0                   0.006538
# 1                   0.026632
# 2                   0.012637

# %%
user_behaviour['User Type'] = user_behaviour['User Type'].astype(str)
plt.bar(user_behaviour['User Type'], user_behaviour['Users'])
plt.xlabel('User Type Range')
plt.ylabel('Users')
plt.title('User Type Range vs Users')
plt.savefig('Plots/23.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
user_behaviour['User Type'] = user_behaviour['User Type'].astype(str)
plt.bar(user_behaviour['User Type'], user_behaviour['Revenue'])
plt.xlabel('User Type Range')
plt.ylabel('Revenue')
plt.title('User Type Range vs Revenue')
plt.savefig('Plots/24.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
user_behaviour['User Type'] = user_behaviour['User Type'].astype(str)
plt.bar(user_behaviour['User Type'], user_behaviour['Avg. Session Duration'])
plt.xlabel('User Type Range')
plt.ylabel('Avg. Session Duration')
plt.title('User Type Range vs Avg. Session Duration')
plt.savefig('Plots/25.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
user_behaviour['User Type'] = user_behaviour['User Type'].astype(str)
plt.bar(user_behaviour['User Type'], user_behaviour['New Users'])
plt.xlabel('User Type Range')
plt.ylabel('New Users')
plt.title('User Type Range vs New Users')
plt.savefig('Plots/26.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Product Data

# %%
product_data = pd.read_excel('product_data.xlsx')
product_data
# Out:
#                                                Product  Product Revenue  \
# 0    Faceted Yellow Gold Ring with Unidirectional C...      3406.000000
# 1    Unidirectional Carbon Fiber Ring with Moss Aga...      1707.000000
# 2                                     Custom Gold Ring      1699.000000
# 3                                            Engraving      1569.936845
# 4    Forged Carbon Fiber Ring with Crushed T-Rex In...      1407.000000
# 5    Forged Carbon Fiber Ring with Crushed T-Rex In...      1407.000000
# 6    Unidirectional Carbon Fiber Ring with Moss Aga...      1407.000000
# 7    10mm, 10K Rose gold Ring, Asymmetric design, P...      1380.000000
# 8    Twill Carbon Fiber Ring with Crushed T-Rex & B...      1150.623822
# 9    Forged Carbon Fiber Ring with Crushed T-Rex & ...      1138.000000
# 10   Twill Carbon Fiber Ring with Crushed T-Rex & M...      1138.000000
# 11   Twill Carbon Fiber Ring with Crushed T-Rex & M...      1138.000000
# ...

# %%
product_sales = product_data.groupby('Product')['Product Revenue'].sum().reset_index()

top_selling_products = product_sales.sort_values('Product Revenue', ascending=False)
print(top_selling_products)
top_selling_products.to_excel('top_products.xlsx')
# Out:
#                                                Product  Product Revenue
# 38   Faceted Yellow Gold Ring with Unidirectional C...      3406.000000
# 226  Unidirectional Carbon Fiber Ring with Moss Aga...      1707.000000
# 9                                     Custom Gold Ring      1699.000000
# 32                                           Engraving      1569.936845
# 54   Forged Carbon Fiber Ring with Crushed T-Rex In...      1407.000000
# 56   Forged Carbon Fiber Ring with Crushed T-Rex In...      1407.000000
# 229  Unidirectional Carbon Fiber Ring with Moss Aga...      1407.000000
# 0    10mm, 10K Rose gold Ring, Asymmetric design, P...      1380.000000
# 192  Twill Carbon Fiber Ring with Crushed T-Rex & B...      1150.623822
# 193  Twill Carbon Fiber Ring with Crushed T-Rex & M...      1138.000000
# 194  Twill Carbon Fiber Ring with Crushed T-Rex & M...      1138.000000
# 47   Forged Carbon Fiber Ring with Crushed T-Rex & ...      1138.000000
# ...

# %%
product_purchases = product_data.groupby('Product')['Quantity'].sum().reset_index()
top_quantity_products = product_purchases.sort_values('Quantity', ascending=False)
print(top_quantity_products)
top_quantity_products.to_excel('top_quantity.xlsx')
# Out:
#                                                Product  Quantity
# 32                                           Engraving        32
# 122                                          Test Ring        29
# 128                               Test Rings - 6.00 mm        19
# 124                               Test Rings - 2.00 mm        18
# 129                               Test Rings - 7.00 mm        15
# 130                               Test Rings - 8.00 mm        11
# 110            Rush Production - UPS Shipping Included         9
# 126                               Test Rings - 4.00 mm         8
# 127                               Test Rings - 5.00 mm         8
# 99                          Resize & Exchange Fee - 49         5
# 42   Forged Carbon Fiber Ring with Bloodwood Inner ...         3
# 226  Unidirectional Carbon Fiber Ring with Moss Aga...         3
# 229  Unidirectional Carbon Fiber Ring with Moss Aga...         3
# ...

# %% [markdown]
# Browser Level

# %%
browser_data = pd.read_excel('browser_data.xlsx')
browser_data
# Out:
#              Browser  Users  New Users  Sessions  Bounce Rate  \
# 0             Chrome   5110       5048      7890     0.666920
# 1             Safari   4499       4487      6626     0.711591
# 2    Safari (in-app)   1706       1707      1815     0.482094
# 3    Android Webview    566        563       619     0.476575
# 4   Samsung Internet    174        172       188     0.797872
# 5        Amazon Silk    100         99       147     0.891156
# 6               Edge     74         73       103     0.427184
# 7            Firefox     72         70       130     0.492308
# 8              Opera     25         24        42     0.523810
# 9         UC Browser      3          3         3     0.000000
# 10               NaN  12334      12251     17568     0.658015
#
#     Pages / Session  Avg. Session Duration  Transactions       Revenue  \
# 0          2.931686             154.577060            90  30576.952220
# 1          2.173710             109.686991           113  33025.725142
# ...

# %%
browser_data['Browser'] = browser_data['Browser'].astype(str)
plt.bar(browser_data['Browser'], browser_data['Users'])
plt.xlabel('Browsers')
plt.ylabel('Users')
plt.title('Browser vs Users')
plt.xticks(rotation= 90)
plt.savefig('Plots/27.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
browser_data['Browser'] = browser_data['Browser'].astype(str)
plt.bar(browser_data['Browser'], browser_data['Revenue'])
plt.xlabel('Browsers')
plt.ylabel('Revenue')
plt.title('Browser vs Revenue')
plt.xticks(rotation= 90)
plt.savefig('Plots/28.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Device Level

# %%
device_data = pd.read_excel('device_data.xlsx')
device_data
# Out:
#   Device Category  Users  New Users  Sessions  Bounce Rate  Pages / Session  \
# 0          mobile   9498       9442     13248     0.669007         2.161156
# 1         desktop   2522       2481      3886     0.608338         3.889089
# 2          tablet    329        328       434     0.767281         1.739631
# 3             NaN  12349      12251     17568     0.658015         2.532958
#
#    Avg. Session Duration  Transactions       Revenue  \
# 0              92.533288           149  41019.890399
# 1             235.739835            73  28443.386963
# 2              48.011521             0      0.000000
# 3             123.110371           222  69463.277362
#
#    Ecommerce Conversion Rate
# 0                   0.011247
# 1                   0.018785
# 2                   0.000000
# 3                   0.012637

# %%
device_data['Device Category'] = device_data['Device Category'].astype(str)
plt.bar(device_data['Device Category'], device_data['Revenue'])
plt.xlabel('Device Category')
plt.ylabel('Revenue')
plt.title('Device Category vs Revenue')
plt.xticks(rotation= 90)
plt.savefig('Plots/29.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
device_data['Device Category'] = device_data['Device Category'].astype(str)
plt.bar(device_data['Device Category'], device_data['Users'])
plt.xlabel('Device Category')
plt.ylabel('Users')
plt.title('Device Category vs Users')
plt.xticks(rotation= 90)
plt.savefig('Plots/30.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
device_data['Device Category'] = device_data['Device Category'].astype(str)
plt.bar(device_data['Device Category'], device_data['Avg. Session Duration'])
plt.xlabel('Device Category')
plt.ylabel('Avg. Session Duration')
plt.title('Device Category vs Avg. Session Duration')
plt.xticks(rotation= 90)
plt.savefig('Plots/31.png', dpi=300, bbox_inches='tight')
plt.show()
